# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATAPATH = '/home/kinit/VNET-NAnoDec/src/anomaly_detection/model/results/basic_bigsubset_10e_stats.csv'

# %%
data = pd.read_csv(DATAPATH)

# %%
data.columns
# Out:
# Index(['epoch', 'train_loss', 'valid_loss', 'valid_acc'], dtype='object')

# %%
data.head()
# Out:
#    epoch    train_loss   valid_loss  valid_acc
# 0      1  32617.517196   792.178723   0.880680
# 1      2  12179.762159   634.771375   0.888975
# 2      3   7671.501186   807.845291   0.888067
# 3      4   6031.210748  5380.972532   0.892655
# 4      5   5731.386477   587.155206   0.891940

# %%
plt.plot(data['epoch'], data['train_loss'], label='Train Loss')
plt.plot(data['epoch'], data['valid_loss'], label='Valid Loss')
plt.title("Model Training Progress Visualization")
plt.legend()
plt.show()
